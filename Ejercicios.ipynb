# %% [markdown]
# <a href="https://colab.research.google.com/github/aibarra002/curso-introducccion-programacion-cientifica/blob/main/Ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejercicio 1 — Inventario de la tienda**
#
# Una tienda pequeña tiene el siguiente inventario:
#
# Productos y precios (en pesos colombianos):
# - Cuaderno: 3500
# - Lápiz: 800
# - Café: 6200.50
# Cantidad a comprar: 3 cuadernos, 5 lápices
# La tienda tiene actualmente descuentos activos: no

# %% [markdown]
#  TODO: declare nombre_producto (str) con el nombre de un producto de su elección
#
#  TODO: declare precio_cuaderno (int) y precio_lapiz (int)
#
#  TODO: declare precio_cafe (float)
#
#  TODO: declare hay_descuento (bool) indicando si la tienda tiene descuentos activos
#
#  TODO: declare cantidad_cuadernos (int) y cantidad_lapices (int)
#
# TODO: verifique con type() el tipo de cada una de las variables anteriores
# Requisitos:
#
# Declare las siete variables indicadas, con el tipo de dato correcto para cada una (int, float, str, bool).
# Verifique con type() que cada variable quedó con el tipo esperado.

# %%
# Ejercicio 1 — Inventario de la tienda
nombre_producto = "Cuaderno"       # str
precio_cuaderno = 3500             # int
precio_lapiz = 800                 # int
precio_cafe = 6200.50              # float
hay_descuento = False              # bool
cantidad_cuadernos = 3             # int
cantidad_lapices = 5               # int

# Verificación de tipos
print("Tipo de nombre_producto:", type(nombre_producto))
print("Tipo de precio_cuaderno:", type(precio_cuaderno))
print("Tipo de precio_lapiz:", type(precio_lapiz))
print("Tipo de precio_cafe:", type(precio_cafe))
print("Tipo de hay_descuento:", type(hay_descuento))
print("Tipo de cantidad_cuadernos:", type(cantidad_cuadernos))
print("Tipo de cantidad_lapices:", type(cantidad_lapices))
# Out:
# Tipo de nombre_producto: <class 'str'>
# Tipo de precio_cuaderno: <class 'int'>
# Tipo de precio_lapiz: <class 'int'>
# Tipo de precio_cafe: <class 'float'>
# Tipo de hay_descuento: <class 'bool'>
# Tipo de cantidad_cuadernos: <class 'int'>
# Tipo de cantidad_lapices: <class 'int'>

# %% [markdown]
# ##Ejercicio 2 — Total de la compra y descuento
# Retome las variables del Ejercicio 1.
#
# TODO: calcule total_cuadernos (precio_cuaderno * cantidad_cuadernos) y muéstrelo con print()
# TODO: calcule total_lapices (precio_lapiz * cantidad_lapices) y muéstrelo con print()
# TODO: calcule total_general sumando total_cuadernos, total_lapices y precio_cafe
# TODO: calcule un descuento del 10% sobre total_general
# TODO: calcule total_con_descuento restando el descuento a total_general
# Requisitos: use los operadores de multiplicación (*), suma (+) y resta (-).

# %%
total_cuadernos = precio_cuaderno * cantidad_cuadernos
print(total_cuadernos)

total_lapices = precio_lapiz * cantidad_lapices
print(total_lapices)

total_general = total_cuadernos + total_lapices + precio_cafe
print(total_general)

descuento = total_general * 0.10
print(descuento)

total_con_descuento = total_general - descuento
print(total_con_descuento)
# Out:
# 10500
# 4000
# 20700.5
# 2070.05
# 18630.45

# %% [markdown]
# #Ejercicio 3 — Reparto en paquetes
# Retome cantidad_cuadernos del Ejercicio 1 y precio_cafe del Ejercicio 1.
#
# TODO: calcule cuántos paquetes completos de 4 cuadernos se pueden armar con
# cantidad_cuadernos (división entera)
# TODO: calcule cuántos cuadernos sueltos quedan (módulo)
# TODO: calcule el precio del café elevado al cuadrado
# TODO: muestre los tres resultados con print()
# Requisitos: use división entera (//), módulo (%) y potencia (**).

# %%
paquetes_completos = cantidad_cuadernos // 4
print(paquetes_completos)

cuadernos_sueltos = cantidad_cuadernos % 4
print(cuadernos_sueltos)

cafe_cuadrado = precio_cafe ** 2
print(cafe_cuadrado)
# Out:
# 0
# 3
# 38446200.25

# %% [markdown]
# #Ejercicio 4 — Comparar precios de café
# Dos marcas de café cuestan, respectivamente, 15900 y 14500 pesos la libra.
#
# TODO: declare precio_marca_a y precio_marca_b
# TODO: evalúe y muestre con print() cuál marca es más barata
# TODO: evalúe y muestre con print() si ambas marcas cuestan lo mismo
# Requisitos: use al menos dos operadores de comparación distintos (<, >, ==, etc.).

# %%
precio_marca_a = 15900
precio_marca_b = 14500

print("¿La marca A es más barata?", precio_marca_a < precio_marca_b)
print("¿La marca B es más barata?", precio_marca_b < precio_marca_a)
print("¿Ambas marcas cuestan lo mismo?", precio_marca_a == precio_marca_b)
# Out:
# ¿La marca A es más barata? False
# ¿La marca B es más barata? True
# ¿Ambas marcas cuestan lo mismo? False

# %% [markdown]
# #Ejercicio 5 — Promedio y comparación de temperaturas
# Trabaje con el siguiente conjunto de datos:
#
# Temperaturas registradas (en grados Celsius):
# - Lunes: 18.5
# - Martes: 21.0
# - Miércoles: 19.8
# Temperatura promedio de referencia de la semana: 20.0
# TODO: declare temp_lunes, temp_martes, temp_miercoles y temp_promedio_semana (float)
# TODO: calcule el promedio de los tres días y muéstrelo con print()
# TODO: calcule la diferencia entre la temperatura del martes y la del lunes
# TODO: evalúe y muestre con print() si el martes fue más caluroso que el promedio de referencia
# TODO: evalúe y muestre con print() si el miércoles fue igual al promedio de referencia
# TODO: evalúe y muestre con print() si el lunes fue el día más frío de los tres
# (comparándolo con los otros dos)
# Requisitos: use el operador de división (/) para el promedio y al menos tres operadores de comparación distintos.

# %%
temp_lunes = 18.5
temp_martes = 21.0
temp_miercoles = 19.8
temp_promedio_semana = 20.0

promedio = (temp_lunes + temp_martes + temp_miercoles) / 3
print("Promedio:", promedio)

diferencia = temp_martes - temp_lunes
print("Diferencia:", diferencia)

print("¿El martes fue más caluroso que el promedio de referencia?",
      temp_martes > temp_promedio_semana)

print("¿El miércoles fue igual al promedio de referencia?",
      temp_miercoles == temp_promedio_semana)

print("¿El lunes fue el día más frío?",
      temp_lunes < temp_martes and temp_lunes < temp_miercoles)
# Out:
# Promedio: 19.766666666666666
# Diferencia: 2.5
# ¿El martes fue más caluroso que el promedio de referencia? True
# ¿El miércoles fue igual al promedio de referencia? False
# ¿El lunes fue el día más frío? True

# %% [markdown]
# #Ejercicio 6 — Temperatura templada y día caluroso
# Retome las variables de temperatura del Ejercicio 5.
#
# TODO: evalúe y muestre con print() si el lunes tuvo una temperatura "templada",
# entendida como un valor entre 15 y 25 grados (combine dos comparaciones con "and")
# TODO: evalúe y muestre con print() si al menos uno de los tres días superó los 20 grados
# (combine tres comparaciones con "or")
# Requisitos: use el operador lógico and sobre dos comparaciones y el operador lógico or sobre tres comparaciones.

# %%
print("¿El lunes tuvo una temperatura templada?",
      temp_lunes >= 15 and temp_lunes <= 25)

print("¿Al menos un día superó los 20 grados?",
      temp_lunes > 20 or temp_martes > 20 or temp_miercoles > 20)
# Out:
# ¿El lunes tuvo una temperatura templada? True
# ¿Al menos un día superó los 20 grados? True

# %% [markdown]
# #Ejercicio 7 — Factura de servicios y consumo normal
# Un hogar consumió 142 kWh este mes. La tarifa es de 623.5 pesos por kWh. El proveedor considera "consumo normal" un valor entre 100 y 200 kWh.
#
# TODO: declare consumo_kwh (int) y tarifa_kwh (float)
# TODO: calcule el total a pagar (consumo_kwh * tarifa_kwh) y muéstrelo con print()
# TODO: evalúe si consumo_kwh es mayor o igual a 100
# TODO: evalúe si consumo_kwh es menor o igual a 200
# TODO: combine ambas evaluaciones con "and" y muestre con print() si el consumo es normal
# Requisitos: use el operador de multiplicación (*) y el operador lógico and sobre dos comparaciones.

# %%
consumo_kwh = 142
tarifa_kwh = 623.5

total_pagar = consumo_kwh * tarifa_kwh
print("Total a pagar:", total_pagar)

print("¿Es mayor o igual a 100?", consumo_kwh >= 100)

print("¿Es menor o igual a 200?", consumo_kwh <= 200)

consumo_normal = consumo_kwh >= 100 and consumo_kwh <= 200
print("¿El consumo es normal?", consumo_normal)
# Out:
# Total a pagar: 88537.0
# ¿Es mayor o igual a 100? True
# ¿Es menor o igual a 200? True
# ¿El consumo es normal? True

# %% [markdown]
# #Ejercicio 8 — Promedio de calificaciones y aprobación
# Un estudiante obtuvo tres notas parciales en un curso: 4.2, 3.5 y 4.8 (sobre 5.0).
#
# TODO: declare las tres notas parciales
# TODO: calcule el promedio y muéstrelo con print()
# TODO: evalúe y muestre con print() si el promedio es mayor o igual a 3.0 (aprobación)
# Requisitos: combine un operador aritmético (para el promedio) con uno de comparación (para la aprobación).

# %%
nota1 = 4.2
nota2 = 3.5
nota3 = 4.8

promedio = (nota1 + nota2 + nota3) / 3
print("Promedio:", promedio)

print("¿Aprobó?", promedio >= 3.0)
# Out:
# Promedio: 4.166666666666667
# ¿Aprobó? True

# %% [markdown]
# #Ejercicio 9 — Aprobación y asistencia
# Retome el promedio del Ejercicio 8. El estudiante además tuvo una asistencia de 85% al curso.
#
# TODO: declare asistencia_porcentaje
# TODO: evalúe si el promedio del Ejercicio 8 corresponde a una reprobación (menor a 3.0)
# TODO: muestre con print(), usando "not", si el estudiante NO reprobó
# Requisitos: use el operador lógico not sobre una comparación.

# %%
asistencia_porcentaje = 85

reprobo = promedio < 3.0

print("¿El estudiante NO reprobó?", not (promedio < 3.0))
# Out:
# ¿El estudiante NO reprobó? True

# %% [markdown]
# #Ejercicio 10 — Intercambiar dos precios
# Una ferretería tiene dos repuestos con precios mal registrados: el precio_tornillo quedó guardado como el de la tuerca, y viceversa. Corrija el error intercambiando los valores de las dos variables, sin asignar los valores correctos a mano — debe usar una variable temporal para el intercambio.
#
# precio_tornillo = 250
# precio_tuerca = 180
#
# TODO: muestre con print() los valores antes de intercambiar
# TODO: intercambie los valores de precio_tornillo y precio_tuerca
# usando una variable temporal (por ejemplo, "temporal")
# TODO: muestre con print() los valores después de intercambiar, para confirma
# Requisitos: use una variable temporal adicional para el intercambio; no reescriba los números directamente en cada variable.

# %%
precio_tornillo = 250
precio_tuerca = 180

# Valores antes de intercambiar
print("Antes:")
print("Precio tornillo:", precio_tornillo)
print("Precio tuerca:", precio_tuerca)

# Intercambio usando una variable temporal
temporal = precio_tornillo
precio_tornillo = precio_tuerca
precio_tuerca = temporal

# Valores después de intercambiar
print("Después:")
print("Precio tornillo:", precio_tornillo)
print("Precio tuerca:", precio_tuerca)
# Out:
# Antes:
# Precio tornillo: 250
# Precio tuerca: 180
# Después:
# Precio tornillo: 180
# Precio tuerca: 250

# %%
# Celda de verificación — ejecútela al final, después de todo lo demás

assert type(precio_cuaderno) == int, "precio_cuaderno debería ser int"
assert type(precio_cafe) == float, "precio_cafe debería ser float"
assert type(temp_lunes) == float, "temp_lunes debería ser float"
assert isinstance(precio_cafe > precio_cuaderno, bool), "la comparación debe dar un booleano"

print("Verificación completada sin errores.")
# Out:
# Verificación completada sin errores.
